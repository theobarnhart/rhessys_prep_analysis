# %% [markdown]
# ### Script to convert LANDIS Biomass to forest LAI
#
# Outputs a geoTIFF for ingestion into GRASS and RHESSys
#
# Blank cells (biomass of 0) are assumed to be grass and given an LAI of 1, this is an assumption that will need to be documented in the methods.

# %%
def biomass2LAI(x,sla,leaf_stem):
    '''
    Convert biomass to lai based on the specific leaf area.
    
    x: array of biomass values in g/m2
    sla: specific leaf area m2/kg c
    leaf_stem: ratio of leaf mass to stem mass
    '''
    x /= 1000. # g/m2 > kg/m2
    leaf = (x*leaf_stem) / (1.+leaf_stem) # compute leaf wet biomass
    lai = leaf * sla # convert leaf dry biomass to leaf area

    return lai

# %%
import gdal
import glob

# %%
rastpth = './data/LAI_Boulder_crop.tif'
ds = gdal.Open(rastpth)
rast = np.array(ds.GetRasterBand(1).ReadAsArray(),dtype=float)
rast[rast<0] = np.NaN
mask = rast.copy()
mask[np.isnan(mask)==0] = 1

# %%
files = glob.glob('./data/LANDIS_output/climate_change/*/*/*.tiff')

# %%
dat = pd.DataFrame({'filename':files})

# %%
def get_run(fl):
    return int(fl.split("/")[-2].split('_')[-1])

# %%
def get_scenario(fl):
    
    key = fl.split("/")[-2][:-2]
    
    if key == 'BDA+FIRE_+4C_minus15%precip':
        out = 'PGW_LP'
    
    if key == 'BDA+FIRE_+4C_+15%precip':
        out = 'PGW_MP'
        
    return out

# %%
def get_year(fl):
    
    yr = int(fl.split('/')[-1].split('-')[-1].split('_')[0])
    yr -= 10
    yr += 2000
    
    return yr

# %%
dat['run'] = dat.filename.map(get_run)
dat['scenario'] = dat.filename.map(get_scenario)
dat['year'] = dat.filename.map(get_year)

# %%
dat.sort_values('year',inplace=True)
dat = dat.loc[dat.year!=1990]

# %%
dat
# Out:
#                                              filename  run scenario  year
# 25  ./data/LANDIS_output/climate_change/PGW_less_P...    5   PGW_LP  2000
# 49  ./data/LANDIS_output/climate_change/PGW_more_P...    2   PGW_MP  2000
# 1   ./data/LANDIS_output/climate_change/PGW_less_P...    1   PGW_LP  2000
# 13  ./data/LANDIS_output/climate_change/PGW_less_P...    2   PGW_LP  2000
# 61  ./data/LANDIS_output/climate_change/PGW_more_P...    3   PGW_MP  2000
# 37  ./data/LANDIS_output/climate_change/PGW_more_P...    1   PGW_MP  2000
# 52  ./data/LANDIS_output/climate_change/PGW_more_P...    2   PGW_MP  2010
# 64  ./data/LANDIS_output/climate_change/PGW_more_P...    3   PGW_MP  2010
# 4   ./data/LANDIS_output/climate_change/PGW_less_P...    1   PGW_LP  2010
# 40  ./data/LANDIS_output/climate_change/PGW_more_P...    1   PGW_MP  2010
# 16  ./data/LANDIS_output/climate_change/PGW_less_P...    2   PGW_LP  2010
# 28  ./data/LANDIS_output/climate_change/PGW_less_P...    5   PGW_LP  2010
# 53  ./data/LANDIS_output/climate_change/PGW_more_P...    2   PGW_MP  2020
# 29  ./data/LANDIS_output/climate_change/PGW_less_P...    5   PGW_LP  2020
# 65  ./data/LANDIS_output/climate_change/PGW_more_P...    3   PGW_MP  2020
# 17  ./data/LANDIS_output/climate_change/PGW_less_P...    2   PGW_LP  2020
# 41  ./data/LANDIS_output/climate_change/PGW_more_P...    1   PGW_MP  2020
# 5   ./data/LANDIS_output/climate_change/PGW_less_P...    1   PGW_LP  2020
# 42  ./data/LANDIS_output/climate_change/PGW_more_P...    1   PGW_MP  2030
# 6   ./data/LANDIS_output/climate_change/PGW_less_P...    1   PGW_LP  2030
# 30  ./data/LANDIS_output/climate_change/PGW_less_P...    5   PGW_LP  2030
# 66  ./data/LANDIS_output/climate_change/PGW_more_P...    3   PGW_MP  2030
# 18  ./data/LANDIS_output/climate_change/PGW_less_P...    2   PGW_LP  2030
# 54  ./data/LANDIS_output/climate_change/PGW_more_P...    2   PGW_MP  2030
# 19  ./data/LANDIS_output/climate_change/PGW_less_P...    2   PGW_LP  2040
# 31  ./data/LANDIS_output/climate_change/PGW_less_P...    5   PGW_LP  2040
# 43  ./data/LANDIS_output/climate_change/PGW_more_P...    1   PGW_MP  2040
# 7   ./data/LANDIS_output/climate_change/PGW_less_P...    1   PGW_LP  2040
# 55  ./data/LANDIS_output/climate_change/PGW_more_P...    2   PGW_MP  2040
# 67  ./data/LANDIS_output/climate_change/PGW_more_P...    3   PGW_MP  2040
# ..                                                ...  ...      ...   ...
# 9   ./data/LANDIS_output/climate_change/PGW_less_P...    1   PGW_LP  2060
# 21  ./data/LANDIS_output/climate_change/PGW_less_P...    2   PGW_LP  2060
# 69  ./data/LANDIS_output/climate_change/PGW_more_P...    3   PGW_MP  2060
# 33  ./data/LANDIS_output/climate_change/PGW_less_P...    5   PGW_LP  2060
# 45  ./data/LANDIS_output/climate_change/PGW_more_P...    1   PGW_MP  2060
# 57  ./data/LANDIS_output/climate_change/PGW_more_P...    2   PGW_MP  2060
# 10  ./data/LANDIS_output/climate_change/PGW_less_P...    1   PGW_LP  2070
# 58  ./data/LANDIS_output/climate_change/PGW_more_P...    2   PGW_MP  2070
# 70  ./data/LANDIS_output/climate_change/PGW_more_P...    3   PGW_MP  2070
# 34  ./data/LANDIS_output/climate_change/PGW_less_P...    5   PGW_LP  2070
# 46  ./data/LANDIS_output/climate_change/PGW_more_P...    1   PGW_MP  2070
# 22  ./data/LANDIS_output/climate_change/PGW_less_P...    2   PGW_LP  2070
# 59  ./data/LANDIS_output/climate_change/PGW_more_P...    2   PGW_MP  2080
# 35  ./data/LANDIS_output/climate_change/PGW_less_P...    5   PGW_LP  2080
# 47  ./data/LANDIS_output/climate_change/PGW_more_P...    1   PGW_MP  2080
# 23  ./data/LANDIS_output/climate_change/PGW_less_P...    2   PGW_LP  2080
# 11  ./data/LANDIS_output/climate_change/PGW_less_P...    1   PGW_LP  2080
# 71  ./data/LANDIS_output/climate_change/PGW_more_P...    3   PGW_MP  2080
# 50  ./data/LANDIS_output/climate_change/PGW_more_P...    2   PGW_MP  2090
# 38  ./data/LANDIS_output/climate_change/PGW_more_P...    1   PGW_MP  2090
# 26  ./data/LANDIS_output/climate_change/PGW_less_P...    5   PGW_LP  2090
# 62  ./data/LANDIS_output/climate_change/PGW_more_P...    3   PGW_MP  2090
# 14  ./data/LANDIS_output/climate_change/PGW_less_P...    2   PGW_LP  2090
# 2   ./data/LANDIS_output/climate_change/PGW_less_P...    1   PGW_LP  2090
# 39  ./data/LANDIS_output/climate_change/PGW_more_P...    1   PGW_MP  2100
# 27  ./data/LANDIS_output/climate_change/PGW_less_P...    5   PGW_LP  2100
# 63  ./data/LANDIS_output/climate_change/PGW_more_P...    3   PGW_MP  2100
# 15  ./data/LANDIS_output/climate_change/PGW_less_P...    2   PGW_LP  2100
# 3   ./data/LANDIS_output/climate_change/PGW_less_P...    1   PGW_LP  2100
# 51  ./data/LANDIS_output/climate_change/PGW_more_P...    2   PGW_MP  2100
#
# [66 rows x 4 columns]

# %%
len(dat)
# Out:
# 66

# %%
sla = 9. # specific leaf area
leaf_stem = 0.0141 # ratio of leaf to stem biomass

# %%
def biomass2LAItiff(fl,sla,leaf_stem,outpath1,outpath2,outpath3,outtiff):
    ds = gdal.Open(fl)
    rast = np.array(ds.GetRasterBand(1).ReadAsArray(),dtype=float)

    srs = ds.GetProjection() # get the projection of the input data set
    transform = ds.GetGeoTransform() # get the limits and resolution of the input data set
    
    # generate lai map
    lai = biomass2LAI(rast,sla,leaf_stem)
    lai[lai==0] = 0.5 # if there is a blank cell, make it into grass with an LAI of 0.5 Blanken et al 2009
    
    # generate land cover type map
    lc = rast.copy()
    lc[lc==0] = 2 # tundra (grass)
    lc[lc!=2] = 4 # forest (evergreen)
    
    # generate land use type map
    lu = lc.copy()
    lu[lu==2] = 11 # alpine
    lu[lu==4] = 12 # subalpine
    
    m,n = np.shape(lai) # get the dimensions of the DEM
    
    # output lai maps
    if outtiff:
        output = gdal.GetDriverByName('GTiff').Create(outpath1,n,m,1,gdal.GDT_Float32) # open the output file
        output.SetGeoTransform(transform) # set coordinates
        output.SetProjection(srs) # set projection
    
        output.GetRasterBand(1).WriteArray(lai)
        output = None # close dataset
    
    # output land cover type map
    if outtiff:
        output = gdal.GetDriverByName('GTiff').Create(outpath2,n,m,1,gdal.GDT_Int16) # open the output file
        output.SetGeoTransform(transform) # set coordinates
        output.SetProjection(srs) # set projection
    
        output.GetRasterBand(1).WriteArray(lc)
        output = None # close dataset
    
    # output land use map
    if outtiff:
        output = gdal.GetDriverByName('GTiff').Create(outpath3,n,m,1,gdal.GDT_Int16) # open the output file
        output.SetGeoTransform(transform) # set coordinates
        output.SetProjection(srs) # set projection
    
        output.GetRasterBand(1).WriteArray(lu)
        output = None # close dataset

# %%
def run_laitiff(dat):
    fl = dat.filename
    
    outpath1 = './data/RHESSys_scenarios/LANDIS_LAI_%s_%s_%s.tiff'%(dat.scenario,dat.run,dat.year)
    outpath2 = './data/RHESSys_scenarios/LANDIS_landcover_%s_%s_%s.tiff'%(dat.scenario,dat.run,dat.year)
    outpath3 = './data/RHESSys_scenarios/LANDIS_landuse_%s_%s_%s.tiff'%(dat.scenario,dat.run,dat.year)
    
    biomass2LAItiff(fl,sla,leaf_stem,outpath1,outpath2,outpath3,True)
    
    return None

# %%
dat.apply(run_laitiff,axis=1)
# Out:
# 25    None
# 49    None
# 1     None
# 13    None
# 61    None
# 37    None
# 52    None
# 64    None
# 4     None
# 40    None
# 16    None
# 28    None
# 53    None
# 29    None
# 65    None
# 17    None
# 41    None
# 5     None
# 42    None
# 6     None
# 30    None
# 66    None
# 18    None
# 54    None
# 19    None
# 31    None
# 43    None
# 7     None
# 55    None
# 67    None
#       ...
# 9     None
# 21    None
# 69    None
# 33    None
# 45    None
# 57    None
# 10    None
# 58    None
# 70    None
# 34    None
# 46    None
# 22    None
# 59    None
# 35    None
# 47    None
# 23    None
# 11    None
# 71    None
# 50    None
# 38    None
# 26    None
# 62    None
# 14    None
# 2     None
# 39    None
# 27    None
# 63    None
# 15    None
# 3     None
# 51    None
# dtype: object
