# %%
import datetime

# %%
def convert_date(df): return datetime.date(int(df.year),int(df.month),int(df.day))

# %%
fl = '/RHESSys/Como/out/opt/test_1/test_1_tmp_basin.daily'
dat = pd.read_table(fl,sep=' ')
dat['datetime'] = dat.apply(convert_date,axis=1)
dat.index = pd.DatetimeIndex(dat.datetime)

# %%
dat['ET'] = dat.trans+dat.evap

# %%
dat.rz_storage.plot(figsize=(15,5))

# %%
dat.ET.plot(figsize=(15,5))

# %%
dat2 = dat.resample('w').mean()

# %%
dat2.ET.plot(figsize=(15,5))

# %%
dat.adj_streamflow.plot(figsize=(15,5))
dat.leakage.plot()
dat.streamflow.plot()
plt.legend()
