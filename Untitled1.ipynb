# %%
data = pd.read_pickle('./data/niwot_new.pcl')

# %%
plt.figure(figsize=(15,5))
plt.plot(data.index,data.Tmin)
plt.ylabel('Temperature [$\degree$C]', fontsize=18)
plt.title('Tmin', fontsize=24, weight='bold')

# %%
plt.figure(figsize=(15,5))
plt.plot(data.index,data.Tmax)
plt.ylabel('Temperature [$\degree$C]', fontsize=18)
plt.title('Tmax', fontsize=24, weight='bold')

# %%
plt.figure(figsize=(15,5))
plt.plot(data.index,data.Tave)
plt.ylabel('Temperature [$\degree$C]', fontsize=18)
plt.title('Tave', fontsize=24, weight='bold')
