# %%
import rhessys.utilities as rut

# %%
data = pd.read_table('/RHESSys/como_test/out/test45_forest3_grow_basin.daily', delim_whitespace=True,low_memory=False)
data.index = pd.date_range(start='2003-10-1',freq='D',periods=len(data))

# %% [raw]
# data['ET'] = data.trans + data.evap

# %%
data.columns
# Out:
# Index([u'day', u'month', u'year', u'basinID', u'lai', u'gpsn', u'plant_resp',
#        u'soil_resp', u'nitrate', u'sminn', u'surfaceN', u'plantc', u'plantn',
#        u'cpool', u'npool', u'litrc', u'litrn', u'soilc', u'soiln', u'gwNO3',
#        u'gwNH4', u'gwDON', u'gwDOC', u'streamflow_NO3', u'streamflow_NH4',
#        u'streamflow_DON', u'streamflow_DOC', u'gwNO3out', u'gwNH4out',
#        u'gwDONout', u'gwDOCout', u'denitrif', u'nitrif', u'DOC', u'DON',
#        u'root_depth', u'nfix', u'nuptake', u'grazingC',
#        u'StreamNO3_from_surface', u'StreamNO3_from_sub'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))
plt.plot(data.index,data.soiln/1000.)
#plt.ylim(0,5)
#plt.ylabel('LAI', fontsize=20)
#plt.title('Forest RHESSys 5.18', fontsize=25)

# %%
plt.figure(figsize=(15,5))
plt.plot(data.index,data.lai)
#plt.ylim(0,5)
#plt.ylabel('LAI', fontsize=20)
#plt.title('Forest RHESSys 5.18', fontsize=25)
plt.axhline(3.5, c='k', lw = 4)

# %%
5.3/data.soilc.max()
# Out:
# 1.0017502277564196

# %%
av = data.ix[int(72683-(365.25*12)):72683,'soiln'].mean()
min_v = data.ix[int(72683-(365.25*12)):72683,'soiln'].min()
max_v = data.ix[int(72683-(365.25*12)):72683,'soiln'].max()

# %%
(max_v - min_v) / av
# Out:
# 0.033801572783275592

# %%
data.ix[int(72683-(365.25*12)):72683,'lai'].mean()
# Out:
# 0.0095213267168605988

# %%
3.5/0.0654
# Out:
# 53.51681957186544

# %%
int(72683-(365.25*12))
# Out:
# 68300

# %%
plt.figure(figsize=(15,5))
plt.plot(data.index,data.streamflow)

# %%
(data['2093-10-1':'2103-9-30'].soilc.max()-data['2093-10-1':'2103-9-30'].soilc.min())/data['2093-10-1':'2103-9-30'].soilc.min()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-da0164c815a3> in <module>()
# ----> 1 (data['2093-10-1':'2103-9-30'].soilc.max()-data['2093-10-1':'2103-9-30'].soilc.min())/data['2093-10-1':'2103-9-30'].soilc.min()
#
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'soilc'
